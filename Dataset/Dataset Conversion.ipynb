# %%
import pandas as pd

# %%
df = pd.read_json('./legal_summarization-master/all_v1.json')

# %%
df = df.to_csv('all_v1.csv')

# %%
pd.read_csv('all_v1.csv').T.to_csv('./dataset/all_v1_transpose.csv', header=False, index=False)

# %%
df = pd.read_csv('all_v1_transpose.csv')

# %%
df.head()
# Out:
#                            doc                        id  \
# 0  Pokemon GO Terms of Service  5786730a6cca83a54c0035b7
# 1  Pokemon GO Terms of Service  57866df76cca83a54c0035a1
# 2  Pokemon GO Terms of Service  5786730a6cca83a54c0035b6
# 3  Pokemon GO Terms of Service  57866df76cca83a54c0035a0
# 4  Pokemon GO Terms of Service  57866df76cca83a54c00359f
#
#                                        original_text  \
# 0  welcome to the pokémon go video game services ...
# 1  by using our services you are agreeing to thes...
# 2  if you want to use certain features of the ser...
# 3  during game play please be aware of your surro...
# 4  subject to your compliance with these terms ni...
#
#                                    reference_summary  \
# 0                                                hi.
# 1  by playing this game you agree to these terms....
# 2  you have to use google pokemon trainer club or...
# 3  don t die or hurt others and if you do it s no...
# ...

# %%
df = pd.read_json('./legal_summarization-master/tldrlegal_v1.json')

# %%
df = df.to_csv('tldrlegal_v1.csv')

# %%
pd.read_csv('tldrlegal_v1.csv').T.to_csv('./dataset/tldrlegal_v1_transpose.csv', header=False, index=False)

# %%
df = pd.read_csv('tldrlegal_v1_transpose.csv')

# %%
df.head()
# Out:
#                            doc                        id  \
# 0  Pokemon GO Terms of Service  5786730a6cca83a54c0035b7
# 1  Pokemon GO Terms of Service  57866df76cca83a54c0035a1
# 2  Pokemon GO Terms of Service  5786730a6cca83a54c0035b6
# 3  Pokemon GO Terms of Service  57866df76cca83a54c0035a0
# 4  Pokemon GO Terms of Service  57866df76cca83a54c00359f
#
#                                        original_text  \
# 0  welcome to the pokémon go video game services ...
# 1  by using our services you are agreeing to thes...
# 2  if you want to use certain features of the ser...
# 3  during game play please be aware of your surro...
# 4  subject to your compliance with these terms ni...
#
#                                    reference_summary  \
# 0                                                hi.
# 1  by playing this game you agree to these terms....
# 2  you have to use google pokemon trainer club or...
# 3  don t die or hurt others and if you do it s no...
# ...

# %%
df = pd.read_json('./legal_summarization-master/tosdr_annotated_v1.json')

# %%
df = df.to_csv('tosdr_annotated_v1.csv')

# %%
pd.read_csv('tosdr_annotated_v1.csv').T.to_csv('./dataset/tosdr_annotated_v1_transpose.csv', header=False, index=False)

# %%
df = pd.read_csv('tosdr_annotated_v1_transpose.csv')

# %%
df.head()
# Out:
#   case_code                                          case_text  \
# 0       1,s                    This service does not track you
# 1       NaN                                                NaN
# 2       2,s  The copyright license that users grant to the ...
# 3       NaN                                                NaN
# 4       1,s  The service uses your personal data to employ ...
#
#                            doc note  \
# 0               Privacy Policy  NaN
# 1               Privacy Policy  NaN
# 2  Additional Terms of Service  NaN
# 3         Terms and Conditions  NaN
# 4               Privacy Policy  NaN
#
#                                        original_text  \
# 0  search encrypt does not track search history i...
# 1  we also provide you additional data control op...
# 2  rvices you grant oath the following worldwide ...
# 3  we may change these terms and conditions to re...
# 4  it also enables us to serve you advertising an...
#
# ...
